# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import GridSearchCV 
from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# Create Grid Search parameters, pre processing pipeline and regressor.

# %%
Y_train = df_train["SalePrice"]
X_train = df_train.loc[:, df_train.columns != "SalePrice"]

# one hot encode categorical features
categorical_features = X_train.select_dtypes(include=['object']).columns

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features)])

## Hyper Parameter Optimization
n_estimators = [1100, 1500]
max_depth = [10, 15]
learning_rate=[0.05,0.20]
min_child_weight=[1,4]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'regressor__n_estimators': n_estimators,
    'regressor__max_depth':max_depth,
    'regressor__learning_rate':learning_rate,
    'regressor__min_child_weight':min_child_weight
    }

# xgboost pipeline
regressor = Pipeline(steps=[
    ("preprocessing", preprocessor),
    ("regressor", XGBRegressor())]
    )

# grid search object
regressor_cv = GridSearchCV(
    estimator = regressor, 
    param_grid = hyperparameter_grid,
    cv = 3, 
    verbose = 1
)

# %% [markdown]
# fit regressor

# %%
regressor_cv.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          Pipeline(steps=[('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl...
#                                                      min_child_weight=None,
#                                                      missing=nan,
#                                                      monotone_constraints=None,
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      predictor=None,
#                                                      random_state=None,
#                                                      reg_alpha=None,
#                                                      reg_lambda=None, ...))]),
#              param_grid={'regressor__learning_rate': [0.05, 0.2],
#                          'regressor__max_depth': [10, 15],
#                          'regressor__min_child_weight': [1, 4],
#                          'regressor__n_estimators': [1100, 1500]},
#              verbose=1)

# %% [markdown]
# grid search results

# %%
pd.DataFrame(regressor_cv.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        2.001017      0.070540         0.031805        0.001685
# 1        2.610376      0.049980         0.044902        0.004210
# 2        1.580752      0.059820         0.019119        0.002860
# 3        2.194642      0.063992         0.033505        0.001783
# 4        3.567076      0.179403         0.056818        0.008749
# 5        4.346302      0.287023         0.084219        0.005892
# 6        2.369805      0.122153         0.039284        0.004536
# 7        3.012010      0.246838         0.050963        0.010187
# 8        1.844528      0.107494         0.026025        0.001486
# 9        2.432038      0.148380         0.035530        0.003339
# 10       1.576252      0.030845         0.025338        0.001247
# 11       2.102564      0.007361         0.030927        0.001501
# 12       2.528100      0.128432         0.042676        0.006861
# 13       3.399841      0.162864         0.055394        0.012178
# 14       2.454034      0.115359         0.037143        0.005752
# 15       3.014381      0.029800         0.043446        0.012244
#
#    param_regressor__learning_rate param_regressor__max_depth  \
# 0                            0.05                         10
# 1                            0.05                         10
# 2                            0.05                         10
# 3                            0.05                         10
# 4                            0.05                         15
# 5                            0.05                         15
# 6                            0.05                         15
# 7                            0.05                         15
# 8                             0.2                         10
# 9                             0.2                         10
# 10                            0.2                         10
# 11                            0.2                         10
# 12                            0.2                         15
# 13                            0.2                         15
# 14                            0.2                         15
# 15                            0.2                         15
#
#    param_regressor__min_child_weight param_regressor__n_estimators  \
# 0                                  1                          1100
# 1                                  1                          1500
# 2                                  4                          1100
# 3                                  4                          1500
# 4                                  1                          1100
# 5                                  1                          1500
# 6                                  4                          1100
# 7                                  4                          1500
# 8                                  1                          1100
# 9                                  1                          1500
# 10                                 4                          1100
# 11                                 4                          1500
# 12                                 1                          1100
# 13                                 1                          1500
# 14                                 4                          1100
# 15                                 4                          1500
#
#                                                params  split0_test_score  \
# 0   {'regressor__learning_rate': 0.05, 'regressor_...           0.760744
# 1   {'regressor__learning_rate': 0.05, 'regressor_...           0.760715
# 2   {'regressor__learning_rate': 0.05, 'regressor_...           0.757726
# 3   {'regressor__learning_rate': 0.05, 'regressor_...           0.757537
# 4   {'regressor__learning_rate': 0.05, 'regressor_...           0.767542
# 5   {'regressor__learning_rate': 0.05, 'regressor_...           0.767542
# 6   {'regressor__learning_rate': 0.05, 'regressor_...           0.749871
# 7   {'regressor__learning_rate': 0.05, 'regressor_...           0.749851
# 8   {'regressor__learning_rate': 0.2, 'regressor__...           0.770292
# 9   {'regressor__learning_rate': 0.2, 'regressor__...           0.770292
# 10  {'regressor__learning_rate': 0.2, 'regressor__...           0.738657
# 11  {'regressor__learning_rate': 0.2, 'regressor__...           0.738657
# 12  {'regressor__learning_rate': 0.2, 'regressor__...           0.759179
# 13  {'regressor__learning_rate': 0.2, 'regressor__...           0.759180
# 14  {'regressor__learning_rate': 0.2, 'regressor__...           0.736541
# 15  {'regressor__learning_rate': 0.2, 'regressor__...           0.736541
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.728111           0.739279         0.742711        0.013542
# 1            0.728048           0.739243         0.742669        0.013554
# 2            0.739057           0.699419         0.732067        0.024311
# 3            0.737480           0.699058         0.731358        0.024263
# 4            0.708646           0.723552         0.733247        0.025002
# 5            0.708646           0.723552         0.733246        0.025002
# 6            0.729341           0.702240         0.727151        0.019507
# 7            0.728803           0.702209         0.726955        0.019493
# 8            0.730441           0.712053         0.737595        0.024308
# 9            0.730441           0.712053         0.737595        0.024308
# 10           0.724514           0.711198         0.724790        0.011212
# 11           0.724513           0.711198         0.724789        0.011212
# 12           0.719224           0.686430         0.721611        0.029748
# 13           0.719223           0.686430         0.721611        0.029748
# 14           0.731774           0.717570         0.728629        0.008058
# 15           0.731774           0.717570         0.728629        0.008058
#
#     rank_test_score
# 0                 1
# 1                 2
# 2                 7
# 3                 8
# 4                 5
# 5                 6
# 6                11
# 7                12
# 8                 4
# 9                 3
# 10               13
# 11               14
# 12               15
# 13               16
# 14                9
# 15               10

# %% [markdown]
# make submission file

# %%
df_test["SalePrice"] = regressor_cv.predict(df_test)

submission = df_test[["Id","SalePrice"]]

submission.to_csv("submission.csv", index=False)
